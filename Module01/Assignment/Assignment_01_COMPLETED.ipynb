# %% [markdown]
# # Assignment 01: Due Thursday 9/5
#
# For this assignment you can use the following packages
# - numpy
# - mtplotlib
#
# Before final sumbission it is a good idea to click on 'Kernel' --> 'Restart & Run All' to make sure your entire notebook runs correctly. It is easy to accidetly modify a value you did not intend to.

# %%
#import the packages here
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# ## Problem 1
# (Problem adapted from scipy.com)
#
# Stirling's Approximation for $ln(n!)$ is:
#
# \begin{equation}
# ln(n!) \approx nln(n) − n.
# \end{equation}
#
# Write a program to output $ln(n!)$ and its Stirling's approximation for $2 < n < 20$. Plot on the same graph the exact value and the approximate value as a function of n. Be sure to lable your curves and axes. **Hint**: the math module (and numpy.math) provides a factorial() method.
#
# **Expected Plot (note this one has 2 < n < 100)**
# ![P1.png](attachment:P1.png)

# %%
x = np.arange(3,100)

exact_values = []
error_less_than_one_percent_found = False

for number in x:
    #print(number)
    factorial_number = float(np.math.factorial(number))
    #print(factorial_number)
    log_factorial = np.log(factorial_number)
    exact_values.append(log_factorial)
    
    approx = number*np.log(number)-number
    exact = log_factorial
    error = 100 * (exact - approx) / exact
    
    if error_less_than_one_percent_found == False:
        print(f'For N={number} // Exact: {round(exact, 3)} // Approx: {round(approx, 3)} // Error: {round(error, 3)}')
        if error < 1.00:
            print(f'error less than one percent at N={number}')
            error_less_than_one_percent_found = True


fig = plt.figure()
axes = fig.add_axes([0.15, 0.1, 0.8, 0.8])
axes.plot(x, exact_values, label='Exact: ln(n!)')
axes.plot(x, x*np.log(x)-x, label='Stirling Approximation: nln(n)-n')
axes.set_xlabel('n')
axes.legend();
# Out:
# For N=3 // Exact: 1.792 // Approx: 0.296 // Error: 83.489
# For N=4 // Exact: 3.178 // Approx: 1.545 // Error: 51.38
# For N=5 // Exact: 4.787 // Approx: 3.047 // Error: 36.351
# For N=6 // Exact: 6.579 // Approx: 4.751 // Error: 27.795
# For N=7 // Exact: 8.525 // Approx: 6.621 // Error: 22.331
# For N=8 // Exact: 10.605 // Approx: 8.636 // Error: 18.568
# For N=9 // Exact: 12.802 // Approx: 10.775 // Error: 15.832
# For N=10 // Exact: 15.104 // Approx: 13.026 // Error: 13.761
# For N=11 // Exact: 17.502 // Approx: 15.377 // Error: 12.144
# For N=12 // Exact: 19.987 // Approx: 17.819 // Error: 10.849
# For N=13 // Exact: 22.552 // Approx: 20.344 // Error: 9.79
# For N=14 // Exact: 25.191 // Approx: 22.947 // Error: 8.91
# For N=15 // Exact: 27.899 // Approx: 25.621 // Error: 8.167
# For N=16 // Exact: 30.672 // Approx: 28.361 // Error: 7.533
# For N=17 // Exact: 33.505 // Approx: 31.165 // Error: 6.985
# For N=18 // Exact: 36.395 // Approx: 34.027 // Error: 6.508
# For N=19 // Exact: 39.34 // Approx: 36.944 // Error: 6.089
# For N=20 // Exact: 42.336 // Approx: 39.915 // Error: 5.719
# For N=21 // Exact: 45.38 // Approx: 42.935 // Error: 5.388
# For N=22 // Exact: 48.471 // Approx: 46.003 // Error: 5.092
# For N=23 // Exact: 51.607 // Approx: 49.116 // Error: 4.826
# For N=24 // Exact: 54.785 // Approx: 52.273 // Error: 4.584
# For N=25 // Exact: 58.004 // Approx: 55.472 // Error: 4.365
# For N=26 // Exact: 61.262 // Approx: 58.711 // Error: 4.164
# For N=27 // Exact: 64.558 // Approx: 61.988 // Error: 3.981
# For N=28 // Exact: 67.89 // Approx: 65.302 // Error: 3.812
# For N=29 // Exact: 71.257 // Approx: 68.652 // Error: 3.656
# For N=30 // Exact: 74.658 // Approx: 72.036 // Error: 3.512
# For N=31 // Exact: 78.092 // Approx: 75.454 // Error: 3.379
# For N=32 // Exact: 81.558 // Approx: 78.904 // Error: 3.255
# For N=33 // Exact: 85.054 // Approx: 82.385 // Error: 3.139
# For N=34 // Exact: 88.581 // Approx: 85.896 // Error: 3.031
# For N=35 // Exact: 92.136 // Approx: 89.437 // Error: 2.929
# For N=36 // Exact: 95.72 // Approx: 93.007 // Error: 2.834
# For N=37 // Exact: 99.331 // Approx: 96.604 // Error: 2.745
# For N=38 // Exact: 102.968 // Approx: 100.228 // Error: 2.661
# For N=39 // Exact: 106.632 // Approx: 103.879 // Error: 2.582
# For N=40 // Exact: 110.321 // Approx: 107.555 // Error: 2.507
# For N=41 // Exact: 114.034 // Approx: 111.256 // Error: 2.436
# For N=42 // Exact: 117.772 // Approx: 114.982 // Error: 2.369
# For N=43 // Exact: 121.533 // Approx: 118.732 // Error: 2.305
# For N=44 // Exact: 125.317 // Approx: 122.504 // Error: 2.245
# For N=45 // Exact: 129.124 // Approx: 126.3 // Error: 2.187
# For N=46 // Exact: 132.953 // Approx: 130.118 // Error: 2.132
# For N=47 // Exact: 136.803 // Approx: 133.957 // Error: 2.08
# For N=48 // Exact: 140.674 // Approx: 137.818 // Error: 2.03
# For N=49 // Exact: 144.566 // Approx: 141.699 // Error: 1.983
# For N=50 // Exact: 148.478 // Approx: 145.601 // Error: 1.937
# For N=51 // Exact: 152.41 // Approx: 149.523 // Error: 1.894
# For N=52 // Exact: 156.361 // Approx: 153.465 // Error: 1.852
# For N=53 // Exact: 160.331 // Approx: 157.425 // Error: 1.812
# For N=54 // Exact: 164.32 // Approx: 161.405 // Error: 1.774
# For N=55 // Exact: 168.327 // Approx: 165.403 // Error: 1.737
# For N=56 // Exact: 172.353 // Approx: 169.42 // Error: 1.702
# For N=57 // Exact: 176.396 // Approx: 173.454 // Error: 1.668
# For N=58 // Exact: 180.456 // Approx: 177.506 // Error: 1.635
# For N=59 // Exact: 184.534 // Approx: 181.575 // Error: 1.604
# For N=60 // Exact: 188.628 // Approx: 185.661 // Error: 1.573
# For N=61 // Exact: 192.739 // Approx: 189.763 // Error: 1.544
# For N=62 // Exact: 196.866 // Approx: 193.882 // Error: 1.516
# For N=63 // Exact: 201.009 // Approx: 198.017 // Error: 1.488
# For N=64 // Exact: 205.168 // Approx: 202.169 // Error: 1.462
# For N=65 // Exact: 209.343 // Approx: 206.335 // Error: 1.437
# For N=66 // Exact: 213.532 // Approx: 210.517 // Error: 1.412
# For N=67 // Exact: 217.737 // Approx: 214.714 // Error: 1.388
# For N=68 // Exact: 221.956 // Approx: 218.927 // Error: 1.365
# For N=69 // Exact: 226.191 // Approx: 223.153 // Error: 1.343
# For N=70 // Exact: 230.439 // Approx: 227.395 // Error: 1.321
# For N=71 // Exact: 234.702 // Approx: 231.65 // Error: 1.3
# For N=72 // Exact: 238.978 // Approx: 235.92 // Error: 1.28
# For N=73 // Exact: 243.269 // Approx: 240.204 // Error: 1.26
# For N=74 // Exact: 247.573 // Approx: 244.501 // Error: 1.241
# For N=75 // Exact: 251.89 // Approx: 248.812 // Error: 1.222
# For N=76 // Exact: 256.221 // Approx: 253.136 // Error: 1.204
# For N=77 // Exact: 260.565 // Approx: 257.473 // Error: 1.187
# For N=78 // Exact: 264.922 // Approx: 261.823 // Error: 1.17
# For N=79 // Exact: 269.291 // Approx: 266.186 // Error: 1.153
# For N=80 // Exact: 273.673 // Approx: 270.562 // Error: 1.137
# For N=81 // Exact: 278.068 // Approx: 274.95 // Error: 1.121
# For N=82 // Exact: 282.474 // Approx: 279.351 // Error: 1.106
# For N=83 // Exact: 286.893 // Approx: 283.764 // Error: 1.091
# For N=84 // Exact: 291.324 // Approx: 288.189 // Error: 1.076
# For N=85 // Exact: 295.767 // Approx: 292.625 // Error: 1.062
# For N=86 // Exact: 300.221 // Approx: 297.074 // Error: 1.048
# For N=87 // Exact: 304.687 // Approx: 301.534 // Error: 1.035
# For N=88 // Exact: 309.164 // Approx: 306.006 // Error: 1.022
# For N=89 // Exact: 313.653 // Approx: 310.489 // Error: 1.009
# For N=90 // Exact: 318.153 // Approx: 314.983 // Error: 0.996
# error less than one percent at N=90

# %% [markdown]
# Now modify your program to output the exact value of $ln(n!)$, Stirling's approximation for it, and the relative error in the approximation for the first value of n where the releative error is less than 1%. The relative error in percent is defined as 100$\times$(exact-approx)/exact. Your output should quote the numbers to 3 decimal places. **Hint**: You may need to increase your n value and you may get an error message. Can you determine why you get an error and how to correctly make this comparison?

# %% [markdown]
# ## Problem 2
# Create a numpy array of 100 7's.

# %%
7*np.ones(100)
# Out:
# array([7., 7., 7., 7., 7., 7., 7., 7., 7., 7., 7., 7., 7., 7., 7., 7., 7.,
#        7., 7., 7., 7., 7., 7., 7., 7., 7., 7., 7., 7., 7., 7., 7., 7., 7.,
#        7., 7., 7., 7., 7., 7., 7., 7., 7., 7., 7., 7., 7., 7., 7., 7., 7.,
#        7., 7., 7., 7., 7., 7., 7., 7., 7., 7., 7., 7., 7., 7., 7., 7., 7.,
#        7., 7., 7., 7., 7., 7., 7., 7., 7., 7., 7., 7., 7., 7., 7., 7., 7.,
#        7., 7., 7., 7., 7., 7., 7., 7., 7., 7., 7., 7., 7., 7., 7.])

# %% [markdown]
# ## Problem 3
# Given the numpy array below. Write a print statement that prints the array below for all values that are larger than 5.

# %%
np.random.seed(0)
arr = np.random.randint(0,11,50)
print(arr)
# Out:
# [ 5  0  3  3  7  9  3  5  2  4  7  6  8  8 10  1  6  7  7  8  1  5  9  8
#   9  4  3  0  3  5  0  2  3  8  1  3  3  3  7  0  1  9  9  0 10  4  7  3
#   2  7]

# %%
'''ANSWER'''
index = []

for number in range(len(arr)):
    if arr[number] <= 5:
        index.append(number)
arr = np.delete(arr, index)
        
print(arr)
# Out:
# [ 7  9  7  6  8  8 10  6  7  7  8  9  8  9  8  7  9  9 10  7  7]

# %% [markdown]
# ## Problem 4
# Write a print statement that prints the below array with all values of '3' removed.

# %%
np.random.seed(0)
arr2 = np.random.randint(0,6,20)
print(arr2)
# Out:
# [4 5 0 3 3 3 1 3 5 2 4 0 0 4 2 1 0 1 5 1]

# %%
'''ANSWER'''
index2 = []

for number in range(len(arr2)):
    if arr2[number] == 3:
        index2.append(number)
arr2 = np.delete(arr2, index2)
        
print(arr2)
# Out:
# [4 5 0 1 5 2 4 0 0 4 2 1 0 1 5 1]

# %% [markdown]
# ## Problem 5a
# Use numpy *random.randn()* to create a random 2D matrix array, that has 1000 entries in each dimension.

# %%
'''ANSWER'''
my_matrix = np.random.randn(1000, 1000)

# %% [markdown]
# ## Problem 5b
# Create a plot that contains two subplots (one row two plots). In each sub plot histogram a column from your 2D matrix created in part a. For example, for the x subplot, histogram the first row of your 2D matrix. For y subplot, histogram the 2nd row of your 2D matrix. Be sure to label your axes. The histograms will allow us to see how our data is distributed.
#
# **Expected plot (Problem 5b)**
# ![P5b.png](attachment:P5b.png)

# %%
fig, axes = plt.subplots(1, 2)

axes[0].hist(my_matrix[0], bins=25)
axes[0].set_xlabel('x random values')

axes[1].hist(my_matrix[1], bins=25)
axes[1].set_xlabel('y random values');

# %% [markdown]
# ## Problem 5c
# Now make a x-y scatter plot of the two columns you histogramed in part b. Be sure to label your axes. This will allow us to see if there are any obious correlations or dependencies on one another in our data.
#
# **Expected plot (Problem 5c)**
# ![P5c.png](attachment:P5c.png)

# %%
fig2 = plt.figure()
axes2 = fig2.add_axes([0.1, 0.1, 0.8, 0.8])
axes2.scatter(my_matrix[0], my_matrix[1])
axes2.set_xlabel('x random values')
axes2.set_ylabel('y random values');

# %% [markdown]
# ## Problem 5d
# The scatter plot form part c is good for investigating dependencies, but it is often hard to judge the density of the data, i.e. how much of our data is at a particular x-y range. To see this more clearly we can make a 2D plot, where color is based on the number of counts containted in our 2D x-y bin.
#
# Make a 2D histogram of your 2D matrix from part a.
#
# **Expected plot(Problem 5d)**
# ![P5d.png](attachment:P5d.png)

# %%
fig3 = plt.figure()
axes3 = fig3.add_axes([0.1, 0.1, 0.8, 0.8])
axes3.hist2d(my_matrix[0], my_matrix[1], bins=25)

axes3.set_xlabel('x random values')
axes3.set_ylabel('y random values')
;
# Out:
# ''

# %% [markdown]
# ## Problem 6
#
# Using *linspace* Generate 100 equally spaced points from 0 to 1. Then plot the cube of the values generated from *linespace* vs the *linspace* generated values.
#
# **Expected plot(Problem 6)**
# ![P6.png](attachment:P6.png)

# %%
x = np.linspace(0, 1, 100)
y = x**3

fig3 = plt.figure()
axes3 = fig3.add_axes([0.1, 0.1, 0.8, 0.8])
axes3.plot(x, y);
axes3.set_title('X$^{3}$ vs X')
# Out:
# Text(0.5, 1.0, 'X$^{3}$ vs X')
